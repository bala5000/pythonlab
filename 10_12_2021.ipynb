# %% [markdown]
# <a href="https://colab.research.google.com/github/bala5000/pythonlab/blob/main/10_12_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([4, 5, 6])
ypoints=np.array([3, 4, 5])

plt.plot(ypoints,marker='o')
plt.plot(xpoints,marker='*')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()
